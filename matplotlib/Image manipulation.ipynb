# %% [markdown]
# See http://matplotlib.org/users/image_tutorial.html

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import PIL

# %%
image = PIL.Image.open("stinkbug.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x375 at 0x7F41388574A8>

# %%
image.format, image.format_description, image.size, image.mode
# Out:
# ('PNG', 'Portable network graphics', (500, 375), 'RGB')

# %%
_, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,6))
ax.imshow(image)
ax.axes.set_ylim(-10, 400)
# Out:
# (-10, 400)

# %%
plt.pcolormesh
