# %%
import pandas as pd
import numpy as np

# %%
results = pd.read_excel("2015 Constituency Results.xlsx")
results.rename(columns={"Unnamed: 1": "Name"}, inplace=True)
results.head()
# Out:
#    Constituency      Name Country Region  Electorate  Turnout  Unnamed: 6  \
# 0             1  Aberavon   Wales  Wales       49821    31523       0.633
# 1             1  Aberavon   Wales  Wales       49821    31523       0.633
# 2             1  Aberavon   Wales  Wales       49821    31523       0.633
# 3             1  Aberavon   Wales  Wales       49821    31523       0.633
# 4             1  Aberavon   Wales  Wales       49821    31523       0.633
#
#          Candidate             Party  Votes  Share  Place
# 0  Stephen Kinnock            Labour  15416  0.489      1
# 1       Peter Bush              UKIP   4971  0.158      2
# 2     Edward Yi He      Conservative   3742  0.119      3
# 3   Duncan Higgitt       Plaid Cymru   3663  0.116      4
# 4     Helen Clarke  Liberal Democrat   1397  0.044      5

# %%
winners = results[results["Place"] == 1]
seconds = results[results["Place"] == 2]

df1 = pd.DataFrame({"Name":winners.Name, "win":winners.Votes,
                    "win party":winners.Party, "Electorate":winners.Electorate})
df2 = pd.DataFrame({"Name":seconds.Name, "2nd":seconds.Votes, "2nd party":seconds.Party})

margins = df1.join(df2.set_index("Name"), on="Name", how="inner")
margins["margin"] = margins["win"] - margins["2nd"]
margins["margin %"] = margins["margin"] / margins.Electorate * 100
margins.set_index("Name", inplace=True)
margins.head()
# Out:
#                                  Electorate    win                win party  \
# Name
# Aberavon                              49821  15416                   Labour
# Aberconwy                             45540  12513             Conservative
# Aberdeen North                        67745  24793  Scottish National Party
# Aberdeen South                        68056  20221  Scottish National Party
# Aberdeenshire West & Kincardine       73445  22949  Scottish National Party
#
#                                    2nd     2nd party  margin   margin %
# Name
# Aberavon                          4971          UKIP   10445  20.965055
# Aberconwy                         8514        Labour    3999   8.781291
# Aberdeen North                   11397        Labour   13396  19.774153
# Aberdeen South                   12991        Labour    7230  10.623604
# Aberdeenshire West & Kincardine  15916  Conservative    7033   9.575873

# %% [markdown]
# # Wales

# %%
wales_names = results[results.Region=="Wales"].Name.unique()
wales = margins.ix[wales_names]
wales[wales["margin %"] <= 5]
# Out:
#                Electorate    win     win party    2nd     2nd party  margin  \
# Name
# Bridgend            59998  14624        Labour  12697  Conservative    1927
# Cardiff North       67193  21709  Conservative  19572        Labour    2137
# Clwyd South         54996  13051        Labour  10649  Conservative    2402
# Gower               61820  15862  Conservative  15835        Labour      27
# Vale of Clwyd       56505  13760  Conservative  13523        Labour     237
# Wrexham             50992  12181        Labour  10350  Conservative    1831
# Ynys Mon            49944  10871        Labour  10642   Plaid Cymru     229
#
#                margin %
# Name
# Bridgend       3.211774
# Cardiff North  3.180391
# Clwyd South    4.367590
# Gower          0.043675
# Vale of Clwyd  0.419432
# Wrexham        3.590759
# Ynys Mon       0.458514

# %% [markdown]
# # Scotland

# %%
scots_names = results[results.Region=="Scotland"].Name.unique()
scots = margins.ix[scots_names]
scots[scots["margin %"] <= 5]
# Out:
#                                        Electorate    win  \
# Name
# Berwickshire, Roxburgh & Selkirk            74179  20145
# Dumfriesshire, Clydesdale & Tweeddale       68483  20759
# Dunbartonshire East                         66966  22093
# Edinburgh South                             65846  19293
# Edinburgh West                              71749  21378
# Orkney & Shetland                           34551   9407
#
#                                                      win party    2nd  \
# Name
# Berwickshire, Roxburgh & Selkirk       Scottish National Party  19817
# Dumfriesshire, Clydesdale & Tweeddale             Conservative  19961
# Dunbartonshire East                    Scottish National Party  19926
# Edinburgh South                                         Labour  16656
# Edinburgh West                         Scottish National Party  18168
# Orkney & Shetland                             Liberal Democrat   8590
#
#                                                      2nd party  margin  \
# Name
# Berwickshire, Roxburgh & Selkirk                  Conservative     328
# Dumfriesshire, Clydesdale & Tweeddale  Scottish National Party     798
# Dunbartonshire East                           Liberal Democrat    2167
# Edinburgh South                        Scottish National Party    2637
# Edinburgh West                                Liberal Democrat    3210
# Orkney & Shetland                      Scottish National Party     817
#
#                                        margin %
# Name
# Berwickshire, Roxburgh & Selkirk       0.442174
# Dumfriesshire, Clydesdale & Tweeddale  1.165253
# Dunbartonshire East                    3.235970
# Edinburgh South                        4.004799
# Edinburgh West                         4.473930
# Orkney & Shetland                      2.364620

# %% [markdown]
# # Running out of time; make a prediction
#
# - UKIP vote will mostly swing back to 2/3 Labour and 1/3 Tories
# - In Scotland, 15% swing away from SNP to next highest party (which doesn't make much difference!!)
# - In England, 10% swing to LibDems, and 5% swing to Tory
#
# Quite how I interpret these is documented in code (ahem!)

# %%
scots_pred = {}
for index, row in scots.iterrows():
    if row.ix["win party"] != "Scottish National Party":
        scots_pred[index] = row.ix["win party"]
    else:
        new_win_votes = row["win"] * 0.85
        new_2nd_votes = row["2nd"] + row["win"] * 0.15
        if new_2nd_votes > new_win_votes:
            scots_pred[index] = row.ix["2nd party"]
        else:
            scots_pred[index] = row.ix["win party"]

scots_pred = pd.DataFrame(list(scots_pred.items()), columns=["Name", "Party"])

# %%
other_names = results[results.Region!="Scotland"].Name.unique()
others = margins.ix[other_names]

# %%
parties = results.Party.unique()

out = {}
for party in parties:
    x = results[results.Party == party]
    out[party] = pd.DataFrame({"Name":x.Name, party:x.Votes})

# %%
df = out[parties[0]]
for party in parties[1:]:
    df = df.join(out[party].set_index("Name"), on="Name", how="outer")
df = df.set_index("Name")
df.head()
# Out:
#                                   Labour    UKIP  Conservative  Plaid Cymru  \
# Name
# Aberavon                         15416.0  4971.0        3742.0       3663.0
# Aberconwy                         8514.0  3467.0       12513.0       3536.0
# Aberdeen North                   11397.0     NaN        5304.0          NaN
# Aberdeen South                   12991.0   897.0       11087.0          NaN
# Aberdeenshire West & Kincardine   2487.0  1006.0       15916.0          NaN
#
#                                  Liberal Democrat  Independent  Green Party  \
# Name
# Aberavon                                   1397.0       1137.0        711.0
# Aberconwy                                  1391.0          NaN        727.0
# Aberdeen North                             2050.0          NaN          NaN
# Aberdeen South                             2252.0        139.0        964.0
# Aberdeenshire West & Kincardine           11812.0        141.0        885.0
#
#                                  Socialist Labour Party   TUSC  \
# Name
# Aberavon                                          352.0  134.0
# Aberconwy                                           NaN    NaN
# Aberdeen North                                      NaN  206.0
# Aberdeen South                                      NaN    NaN
# Aberdeenshire West & Kincardine                     NaN    NaN
#
#                                  Scottish National Party         ...           \
# Name                                                             ...
# Aberavon                                             NaN         ...
# Aberconwy                                            NaN         ...
# Aberdeen North                                   24793.0         ...
# Aberdeen South                                   20221.0         ...
# Aberdeenshire West & Kincardine                  22949.0         ...
#
#                                  The Eccentric Party of Great Britain  \
# Name
# Aberavon                                                          NaN
# Aberconwy                                                         NaN
# Aberdeen North                                                    NaN
# Aberdeen South                                                    NaN
# Aberdeenshire West & Kincardine                                   NaN
#
#                                  The Realists' Party  The Birthday Party  \
# Name
# Aberavon                                         NaN                 NaN
# Aberconwy                                        NaN                 NaN
# Aberdeen North                                   NaN                 NaN
# Aberdeen South                                   NaN                 NaN
# Aberdeenshire West & Kincardine                  NaN                 NaN
#
#                                  Wigan Independents  Wessex Regionalists  \
# Name
# Aberavon                                        NaN                  NaN
# Aberconwy                                       NaN                  NaN
# Aberdeen North                                  NaN                  NaN
# Aberdeen South                                  NaN                  NaN
# Aberdeenshire West & Kincardine                 NaN                  NaN
#
#                                  Reduce VAT in Sport  Give Me Back Elmo  \
# Name
# Aberavon                                         NaN                NaN
# Aberconwy                                        NaN                NaN
# Aberdeen North                                   NaN                NaN
# Aberdeen South                                   NaN                NaN
# Aberdeenshire West & Kincardine                  NaN                NaN
#
#                                  Land Party  \
# Name
# Aberavon                                NaN
# Aberconwy                               NaN
# Aberdeen North                          NaN
# Aberdeen South                          NaN
# Aberdeenshire West & Kincardine         NaN
#
#                                  Magna Carta Conservation Party Great Britain  \
# Name
# Aberavon                                                                  NaN
# Aberconwy                                                                 NaN
# Aberdeen North                                                            NaN
# Aberdeen South                                                            NaN
# Aberdeenshire West & Kincardine                                           NaN
#
#                                  The Evolution Party
# Name
# Aberavon                                         NaN
# Aberconwy                                        NaN
# Aberdeen North                                   NaN
# Aberdeen South                                   NaN
# Aberdeenshire West & Kincardine                  NaN
#
# [5 rows x 129 columns]

# %%
# This is annoying: two "Independent".  But I don't think if affects the final result
df.ix["Witney"]
# Out:
#          Labour    UKIP  Conservative  Plaid Cymru  Liberal Democrat  \
# Name
# Witney  10046.0  5352.0       35201.0          NaN            3953.0
# Witney  10046.0  5352.0       35201.0          NaN            3953.0
#
#         Independent  Green Party  Socialist Labour Party  TUSC  \
# Name
# Witney         94.0       2970.0                     NaN   NaN
# Witney         12.0       2970.0                     NaN   NaN
#
#         Scottish National Party         ...           \
# Name                                    ...
# Witney                      NaN         ...
# Witney                      NaN         ...
#
#         The Eccentric Party of Great Britain  The Realists' Party  \
# Name
# Witney                                   NaN                  NaN
# Witney                                   NaN                  NaN
#
#         The Birthday Party  Wigan Independents  Wessex Regionalists  \
# Name
# Witney                 NaN                 NaN                110.0
# Witney                 NaN                 NaN                110.0
#
#         Reduce VAT in Sport  Give Me Back Elmo  Land Party  \
# Name
# Witney                 56.0               37.0        35.0
# Witney                 56.0               37.0        35.0
#
#         Magna Carta Conservation Party Great Britain  The Evolution Party
# Name
# Witney                                           NaN                  NaN
# Witney                                           NaN                  NaN
#
# [2 rows x 129 columns]

# %%
df["Labour"] += df["UKIP"] * 0.2
df["Conservative"] += df["UKIP"] * 0.4
df["UKIP"] = df["UKIP"] * 0.4
df["Liberal Democrat"] *= 1.1
df["Conservative"] *= 1.05

# %%
winner = [row.argmax() for i, row in df.iterrows()]
df["winner"] = winner
df = df.ix[other_names]
df.head()
# Out:
#                          Labour    UKIP  Conservative  Plaid Cymru  \
# Name
# Aberavon                16410.2  1988.4       6016.92       3663.0
# Aberconwy                9207.4  1386.8      14594.79       3536.0
# Aldershot               10118.6  3301.2      28003.71          NaN
# Aldridge-Brownhills     10385.2  3100.4      24841.32          NaN
# Altrincham & Sale West  14290.4  1618.8      29809.29          NaN
#
#                         Liberal Democrat  Independent  Green Party  \
# Name
# Aberavon                          1536.7       1137.0        711.0
# Aberconwy                         1530.1          NaN        727.0
# Aldershot                         4483.6          NaN       2025.0
# Aldridge-Brownhills               1463.0          NaN        826.0
# Altrincham & Sale West            4658.5          NaN       1983.0
#
#                         Socialist Labour Party   TUSC  \
# Name
# Aberavon                                 352.0  134.0
# Aberconwy                                  NaN    NaN
# Aldershot                                  NaN    NaN
# Aldridge-Brownhills                        NaN    NaN
# Altrincham & Sale West                     NaN    NaN
#
#                         Scottish National Party      ...       \
# Name                                                 ...
# Aberavon                                    NaN      ...
# Aberconwy                                   NaN      ...
# Aldershot                                   NaN      ...
# Aldridge-Brownhills                         NaN      ...
# Altrincham & Sale West                      NaN      ...
#
#                         The Realists' Party  The Birthday Party  \
# Name
# Aberavon                                NaN                 NaN
# Aberconwy                               NaN                 NaN
# Aldershot                               NaN                 NaN
# Aldridge-Brownhills                     NaN                 NaN
# Altrincham & Sale West                  NaN                 NaN
#
#                         Wigan Independents  Wessex Regionalists  \
# Name
# Aberavon                               NaN                  NaN
# Aberconwy                              NaN                  NaN
# Aldershot                              NaN                  NaN
# Aldridge-Brownhills                    NaN                  NaN
# Altrincham & Sale West                 NaN                  NaN
#
#                         Reduce VAT in Sport  Give Me Back Elmo  Land Party  \
# Name
# Aberavon                                NaN                NaN         NaN
# Aberconwy                               NaN                NaN         NaN
# Aldershot                               NaN                NaN         NaN
# Aldridge-Brownhills                     NaN                NaN         NaN
# Altrincham & Sale West                  NaN                NaN         NaN
#
#                         Magna Carta Conservation Party Great Britain  \
# Name
# Aberavon                                                         NaN
# Aberconwy                                                        NaN
# Aldershot                                                        NaN
# Aldridge-Brownhills                                              NaN
# Altrincham & Sale West                                           NaN
#
#                         The Evolution Party        winner
# Name
# Aberavon                                NaN        Labour
# Aberconwy                               NaN  Conservative
# Aldershot                               NaN  Conservative
# Aldridge-Brownhills                     NaN  Conservative
# Altrincham & Sale West                  NaN  Conservative
#
# [5 rows x 130 columns]

# %%
others_pred = pd.DataFrame({"Name":df.index, "Party":df.winner})

pred = pd.concat([scots_pred, others_pred])
pred.tail()
# Out:
#                           Name         Party
# Yeovil                  Yeovil  Conservative
# Ynys Mon              Ynys Mon        Labour
# York Central      York Central        Labour
# York Outer          York Outer  Conservative
# Yorkshire East  Yorkshire East  Conservative

# %%
def get_con_number(name):
    x = set(results[results.Name == name].Constituency)
    assert len(x) == 1
    return list(x)[0]

names = results.Name.unique()
winner = []
for name in names:
    x = pred[pred.Name == name].Party
    winner.append(next(iter(x)))

output = pd.DataFrame({"Name":names, "Winner":winner})
output["Constituency"] = output.Name.map(get_con_number)
output = output[["Constituency", "Name", "Winner"]]
output.head()
# Out:
#    Constituency                             Name                   Winner
# 0             1                         Aberavon                   Labour
# 1             2                        Aberconwy             Conservative
# 2             3                   Aberdeen North  Scottish National Party
# 3             4                   Aberdeen South  Scottish National Party
# 4             5  Aberdeenshire West & Kincardine  Scottish National Party

# %%
output.to_csv("mdaws_prediction.csv")
output.to_excel("mdaws_prediction.xlsx")
