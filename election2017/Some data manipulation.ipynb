# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Get the winners and the margin of win

# %%
results = pd.read_excel("2015 Constituency Results.xlsx")
results.rename(columns={"Unnamed: 1": "Name"}, inplace=True)
results.columns
# Out:
# Index(['Constituency', 'Name', 'Country', 'Region', 'Electorate', 'Turnout',
#        'Unnamed: 6', 'Candidate', 'Party', 'Votes', 'Share', 'Place'],
#       dtype='object')

# %%
winners = results[results["Place"] == 1]
assert np.all( winners["Constituency"] == np.arange(1,651) )
winners.head()
# Out:
#     Constituency                             Name   Country    Region  \
# 0              1                         Aberavon     Wales     Wales
# 9              2                        Aberconwy     Wales     Wales
# 15             3                   Aberdeen North  Scotland  Scotland
# 21             4                   Aberdeen South  Scotland  Scotland
# 28             5  Aberdeenshire West & Kincardine  Scotland  Scotland
#
#     Electorate  Turnout  Unnamed: 6         Candidate  \
# 0        49821    31523       0.633   Stephen Kinnock
# 9        45540    30148       0.662         Guto Bebb
# 15       67745    43936       0.649   Kirsty Blackman
# 21       68056    48551       0.713     Callum McCaig
# 28       73445    55196       0.752  Stuart Donaldson
#
#                       Party  Votes  Share  Place
# 0                    Labour  15416  0.489      1
# 9              Conservative  12513  0.415      1
# 15  Scottish National Party  24793  0.564      1
# 21  Scottish National Party  20221  0.416      1
# 28  Scottish National Party  22949  0.416      1

# %%
seconds = results[results["Place"] == 2]
assert np.all( winners["Constituency"] == np.arange(1,651) )
seconds.head()
# Out:
#     Constituency                             Name   Country    Region  \
# 1              1                         Aberavon     Wales     Wales
# 10             2                        Aberconwy     Wales     Wales
# 16             3                   Aberdeen North  Scotland  Scotland
# 22             4                   Aberdeen South  Scotland  Scotland
# 29             5  Aberdeenshire West & Kincardine  Scotland  Scotland
#
#     Electorate  Turnout  Unnamed: 6          Candidate         Party  Votes  \
# 1        49821    31523       0.633         Peter Bush          UKIP   4971
# 10       45540    30148       0.662       Mary Wimbury        Labour   8514
# 16       67745    43936       0.649      Richard Baker        Labour  11397
# 22       68056    48551       0.713          Anne Begg        Labour  12991
# 29       73445    55196       0.752  Alexander Burnett  Conservative  15916
#
#     Share  Place
# 1   0.158      2
# 10  0.282      2
# 16  0.259      2
# 22  0.268      2
# 29  0.288      2

# %%
winning_votes = winners.set_index("Constituency")["Votes"]
seconds_votes = seconds.set_index("Constituency")["Votes"]
margins = pd.DataFrame({"win":winning_votes, "2nd":seconds_votes})
margins["margin"] = margins["win"] - margins["2nd"]
margins.head()
# Out:
#                 2nd    win  margin
# Constituency
# 1              4971  15416   10445
# 2              8514  12513    3999
# 3             11397  24793   13396
# 4             12991  20221    7230
# 5             15916  22949    7033

# %% [markdown]
# # Process the demographic data
#
# And then normalise is a _vaguely_ reasonable way.

# %%
demo = pd.read_csv("demo_new.csv")
demo.head()
# Out:
#    Unnamed: 0                name  population  age 18-29  age 30-44  \
# 0           0  Berwick-upon-Tweed     75718.0     8867.0    12655.0
# 1           1     Bishop Auckland     87143.0    11815.0    15764.0
# 2           2             Blaydon     88281.0    11388.0    17010.0
# 3           3        Blyth Valley     82174.0    11435.0    15887.0
# 4           4     Durham, City of     94375.0    22609.0    16647.0
#
#    age 45-64  age 65+  households  with a car    white  immigrants    gcse+
# 0    23898.0  16759.0     38261.0     27098.0  74698.0      2403.0  37274.0
# 1    25820.0  16621.0     41200.0     28573.0  86058.0      2102.0  38016.0
# 2    25004.0  17491.0     40046.0     27851.0  86692.0      2256.0  41253.0
# 3    23834.0  14069.0     37070.0     26912.0  81071.0      1912.0  36921.0
# 4    24033.0  15408.0     39659.0     28525.0  90135.0      6662.0  52625.0

# %%
df = pd.DataFrame({"name" : demo["name"], "population" : demo["population"]})
df["age 18-29"] = demo["age 18-29"] / demo["population"]
df["age 30-44"] = demo["age 30-44"] / demo["population"]
df["age 45-64"] = demo["age 45-64"] / demo["population"]
df["age 65+"] = demo["age 65+"] / demo["population"]
df["households"] = demo["households"] / demo["population"]
df["car"] = demo["with a car"] / demo["population"]
df["white"] = demo["white"] / demo["population"]
df["immigrants"] = demo["immigrants"] / demo["population"]
df["gcse+"] = demo["gcse+"] / (demo["age 18-29"] + demo["age 30-44"] + demo["age 45-64"] + demo["age 65+"])
df.head()
# Out:
#                  name  population  age 18-29  age 30-44  age 45-64   age 65+  \
# 0  Berwick-upon-Tweed     75718.0   0.117106   0.167133   0.315618  0.221334
# 1     Bishop Auckland     87143.0   0.135582   0.180898   0.296295  0.190732
# 2             Blaydon     88281.0   0.128997   0.192680   0.283232  0.198129
# 3        Blyth Valley     82174.0   0.139156   0.193334   0.290043  0.171210
# 4     Durham, City of     94375.0   0.239566   0.176392   0.254654  0.163264
#
#    households       car     white  immigrants     gcse+
# 0    0.505309  0.357881  0.986529    0.031736  0.599463
# 1    0.472786  0.327886  0.987549    0.024121  0.542931
# 2    0.453620  0.315481  0.982001    0.025555  0.581905
# 3    0.451116  0.327500  0.986577    0.023268  0.566056
# 4    0.420228  0.302252  0.955073    0.070591  0.668704

# %% [markdown]
# # Stupidly, throw a random forest at it

# %%
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier

# %%
win = pd.DataFrame({"name":winners["Name"], "party":winners["Party"]})
df = df.join(win.set_index("name"), on="name", how="inner")
df.head()
# Out:
#                  name  population  age 18-29  age 30-44  age 45-64   age 65+  \
# 0  Berwick-upon-Tweed     75718.0   0.117106   0.167133   0.315618  0.221334
# 1     Bishop Auckland     87143.0   0.135582   0.180898   0.296295  0.190732
# 2             Blaydon     88281.0   0.128997   0.192680   0.283232  0.198129
# 3        Blyth Valley     82174.0   0.139156   0.193334   0.290043  0.171210
# 4     Durham, City of     94375.0   0.239566   0.176392   0.254654  0.163264
#
#    households       car     white  immigrants     gcse+         party
# 0    0.505309  0.357881  0.986529    0.031736  0.599463  Conservative
# 1    0.472786  0.327886  0.987549    0.024121  0.542931        Labour
# 2    0.453620  0.315481  0.982001    0.025555  0.581905        Labour
# 3    0.451116  0.327500  0.986577    0.023268  0.566056        Labour
# 4    0.420228  0.302252  0.955073    0.070591  0.668704        Labour

# %%
train = np.random.random(size=len(df)) <= 0.8
train, score = df[train], df[~train]

features = train.columns[1:11]
clf = RandomForestClassifier()
y, nums_to_party = pd.factorize(train['party'])
clf.fit(train[features], y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %% [markdown]
# Doesn't actually do too badly...

# %%
preds = nums_to_party[clf.predict(score[features])]
pd.crosstab(score['party'], preds, rownames=['actual'], colnames=['preds'])
# Out:
# preds             Conservative  Labour
# actual
# Conservative                48       7
# Labour                       9      42
# Liberal Democrat             2       0
# Plaid Cymru                  0       1
